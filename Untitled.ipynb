# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('Akuisisi.csv')

# %%
df.head(60)
# Out:
#      Tanggal  Akuisisi listingan toko  Catatan
# 0   Feb 2020                        4      NaN
# 1   Mar 2020                       64      NaN
# 2   Apr 2020                       90      NaN
# 3   Mei 2020                       73      NaN
# 4   Jun 2020                       92      NaN
# 5   Jul 2020                      111      NaN
# 6   Agu 2020                      117      NaN
# 7   Sep 2020                       96      NaN
# 8   Okt 2020                       84      NaN
# 9   Nov 2020                       74      NaN
# 10  Des 2020                       68      NaN
# 11  Jan 2021                       94      NaN
# 12  Feb 2021                       91      NaN
# 13  Mar 2021                       74      NaN
# 14  Apr 2021                       62      NaN
# 15  Mei 2021                        1      NaN

# %%
a = df['Akuisisi listingan toko'].iloc[1:15]

c = a.mean()
d = np.array([c,c,c,c,c,c,c,c,c,c,c,c,c,c])
b = np.array(['mar20','apr20','may20','jun20','jul20','aug20','sep20','okt20','nov20','des20','jan21','feb21','mar21','apr21'])
plt.figure(figsize=(10,4))
plt.plot(b,a, 'r*', label='install')
plt.plot(b,d,'g', label='mean')
plt.xlabel('bulan ke')
plt.ylabel('jumlah install')
plt.legend()
plt.show()

# %%
aa = df.iloc[1:15,0:2]
aa.head(15)
# Out:
#      Tanggal  Akuisisi listingan toko
# 1   Mar 2020                       64
# 2   Apr 2020                       90
# 3   Mei 2020                       73
# 4   Jun 2020                       92
# 5   Jul 2020                      111
# 6   Agu 2020                      117
# 7   Sep 2020                       96
# 8   Okt 2020                       84
# 9   Nov 2020                       74
# 10  Des 2020                       68
# 11  Jan 2021                       94
# 12  Feb 2021                       91
# 13  Mar 2021                       74
# 14  Apr 2021                       62

# %%
aa.plot.scatter(x='Tanggal',y='Akuisisi listingan toko', figsize=(15,8))
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
aa.plot.hist(bins=60)
plt.show()

# %%
df1 = pd.read_csv('Analisis jml.csv')

# %%
df1.head(30)
# Out:
#      Negara/wilayah  Akuisisi pengguna
# 0             India                357
# 1   Amerika Serikat                214
# 2         Indonesia                154
# 3      Inggris Raya                 41
# 4             Rusia                 38
# 5            Brasil                 30
# 6          Filipina                 26
# 7            Jerman                 20
# 8     Korea Selatan                 18
# 9        Bangladesh                 17
# 10          Lainnya                319

# %%
df1.plot.bar(x ='Negara/wilayah', y='Akuisisi pengguna', figsize=(10,3))
plt.show()

# %%
df2 = pd.read_csv('daily_performance.csv')
df2.shape
# Out:
# (432, 8)

# %%
df2.head()
# Out:
#           Date  Pengunjung listingan toko: Semua sumber traffic  \
# 0  25 Feb 2020                                               12
# 1  26 Feb 2020                                               12
# 2  27 Feb 2020                                               15
# 3  28 Feb 2020                                               18
# 4  29 Feb 2020                                               17
#
#    Akuisisi listingan toko: Semua sumber traffic  \
# 0                                              0
# 1                                              1
# 2                                              1
# 3                                              2
# 4                                              0
#
#   Rasio konversi listingan toko: Semua sumber traffic  \
# 0                                                 0%
# 1                                              8,33%
# 2                                              6,67%
# 3                                             11,11%
# ...

# %%
df3= df2.iloc[0:100,0:3]
df4= df2.iloc[100:200,0:3]
df5= df2.iloc[200:300,0:3]
df6= df2.iloc[300:431,0:3]

# %%
df3.head()
# Out:
#           Date  Pengunjung listingan toko: Semua sumber traffic  \
# 0  25 Feb 2020                                               12
# 1  26 Feb 2020                                               12
# 2  27 Feb 2020                                               15
# 3  28 Feb 2020                                               18
# 4  29 Feb 2020                                               17
#
#    Akuisisi listingan toko: Semua sumber traffic
# 0                                              0
# 1                                              1
# 2                                              1
# 3                                              2
# 4                                              0

# %%
df3.max()
# Out:
# Date                                               9 Mei 2020
# Pengunjung listingan toko: Semua sumber traffic            54
# Akuisisi listingan toko: Semua sumber traffic               7
# dtype: object

# %%
df3.mean()
# Out:
# Pengunjung listingan toko: Semua sumber traffic    27.41
# Akuisisi listingan toko: Semua sumber traffic       2.41
# dtype: float64

# %%
df3.plot.bar(x='Date', y='Pengunjung listingan toko: Semua sumber traffic', figsize=(20,5))
plt.show()

# %%
df4.max()
# Out:
# Date                                               9 Sep 2020
# Pengunjung listingan toko: Semua sumber traffic            70
# Akuisisi listingan toko: Semua sumber traffic               8
# dtype: object

# %%
df4.mean()
# Out:
# Pengunjung listingan toko: Semua sumber traffic    43.91
# Akuisisi listingan toko: Semua sumber traffic       3.49
# dtype: float64

# %%
df4.plot.bar(x='Date', y='Pengunjung listingan toko: Semua sumber traffic', figsize=(20,5))
plt.show()

# %%
df5.max()
# Out:
# Date                                               9 Okt 2020
# Pengunjung listingan toko: Semua sumber traffic            79
# Akuisisi listingan toko: Semua sumber traffic               8
# dtype: object

# %%
df5.mean()
# Out:
# Pengunjung listingan toko: Semua sumber traffic    29.90
# Akuisisi listingan toko: Semua sumber traffic       2.57
# dtype: float64

# %%
df5.plot.bar(x='Date', y='Pengunjung listingan toko: Semua sumber traffic', figsize=(20,5))
plt.show()

# %%
df6.max()
# Out:
# Date                                               9 Mar 2021
# Pengunjung listingan toko: Semua sumber traffic            55
# Akuisisi listingan toko: Semua sumber traffic               8
# dtype: object

# %%
df6.mean()
# Out:
# Pengunjung listingan toko: Semua sumber traffic    27.129771
# Akuisisi listingan toko: Semua sumber traffic       2.648855
# dtype: float64

# %%
df6.plot.bar(x='Date', y='Pengunjung listingan toko: Semua sumber traffic', figsize=(20,5))
plt.show()
